# %% [markdown]
# # Problema 1

# %% [markdown]
# Una red transmite datos a $100$ megabits por segundo. Crea una función utilizando *Python* que permita calcular la cantidad de datos transmitidos en una cierta cantidad de tiempo (en segundos). Luego utiliza la función y calcula cuántos datos se transmiten en:
#
# * $45$ segundos
# * $1,5$ minutos
# * $1$ hora

# %% [markdown]
# # Solución

# %%
def calculate_mb(s):
    return 100 * s

def main():
    print(f"En 45 segundos se transmitieron {calculate_mb(45):_} megabits")
    print(f"En 1,5 minutos se transmitieron {int(calculate_mb(1.5 * 60)):_} megabits")
    print(f"En 1 hora se transmitieron {calculate_mb(60*60):_} megabits")
    
main()
# Out:
# En 45 segundos se transmitieron 4_500 megabits
# En 1,5 minutos se transmitieron 9_000 megabits
# En 1 hora se transmitieron 360_000 megabits

# %% [markdown]
# # Problema 2

# %% [markdown]
# Utilizando la función definida en el problema $1$, genera un listado que muestre los datos transmitidos para tiempos desde $0$ hasta $1.000$ segundos con incrementos de $100$ segundos.

# %% [markdown]
# # Solución

# %%
def calculate_mb(s):
    return 100 * s

def main():
    for i in range(0, 1001, 100):
        print(f"En {i} segundos se han transmitido {calculate_mb(i):_} megabits")
        
main()
# Out:
# En 0 segundos se han transmitido 0 megabits
# En 100 segundos se han transmitido 10_000 megabits
# En 200 segundos se han transmitido 20_000 megabits
# En 300 segundos se han transmitido 30_000 megabits
# En 400 segundos se han transmitido 40_000 megabits
# En 500 segundos se han transmitido 50_000 megabits
# En 600 segundos se han transmitido 60_000 megabits
# En 700 segundos se han transmitido 70_000 megabits
# En 800 segundos se han transmitido 80_000 megabits
# En 900 segundos se han transmitido 90_000 megabits
# En 1000 segundos se han transmitido 100_000 megabits

# %% [markdown]
# # Problema 3

# %% [markdown]
# La **latencia** de una red corresponde al tiempo que tarda un paquete de datos en viajar desde el punto de origen al destino. En otras palabras, es el tiempo que transcurre desde que se envía una solicitud de un dispositivo hasta que se recibe una respuesta del servidor u otro dispositivo.
#
# La latencia puede verse afectada por la velocidad de transmisión de los datos a través de los cables o conexiones inalámbricas, la distancia física entre los dispositivos, el tiempo que tarda un computador en procesar o reenviar los datos, etc.
#
# En redes de comunicación, como las videoconferencias, juegos en línea y transmisión de datos en tiempo real, es deseable una baja latencia, de lo contrario pueden existir retrasos en la comunicación y afectar negativamente la experiencia del usuario.

# %% [markdown]
# Según el contexto mencionado, crea una función en *Python* que permita calcular la **latencia real** de una red dada una latencia estimada. Suponga que la latencia real es un $20\%$ mayor a la latencia estimada.
#
# Calcule la latencia real para una latencia estimada de:
#
# a)   $200$ milisegundos.
#
# b)   $149$ milisegundos.
#
# c)   $74$ milisegundos.

# %% [markdown]
# # Solución

# %%
def calculate_real_latency(estimated_latency):
    return estimated_latency * 1.2

def main():
    # a
    print(f"La latencia real de una latencia estimada de 200 milisegundos es {calculate_real_latency(200):.0f} milisegundos")
    
    # b
    print(f"La latencia real de una latencia estimada de 149 milisegundos es {calculate_real_latency(149):.0f} milisegundos")
    
    # c
    print(f"La latencia real de una latencia estimada de 74 milisegundos es {calculate_real_latency(74):.0f} milisegundos")
    
main()
# Out:
# La latencia real de una latencia estimada de 200 milisegundos es 240 milisegundos
# La latencia real de una latencia estimada de 149 milisegundos es 179 milisegundos
# La latencia real de una latencia estimada de 74 milisegundos es 89 milisegundos

# %% [markdown]
# # Problema 4

# %% [markdown]
# Como parte de un proyecto de mejora, en el año $2021$ se instaló un cable de fibra óptica que une España con EEUU. El cable tiene un largo de $6.600$ $km$ y fue colocado por un barco a una velocidad de $1,85$ $km/h$.
#
#
#
# 1.   Determine la forma algebraica de la función que permite determinar el largo del cable instalado (en km) a partir del tiempo transcurrido (en horas). Utilice la instrucción *def* para definir la función en *Python*.
# 2.   Defina variable dependiente e independiente, indicando unidad de medida.
# 3.   Determine el dominio contextualizado de la función.
# 4.   Grafique la función utilizando la biblioteca *Matplotlib* considerando el dominio contextualizado.
# 5.   ¿Cuántos metros de cable se instalaron al transcurrir $148$ horas? ¿Y transcurridas $2.300$ horas?
# 6.   Si se han instalado $3.480$ kilometros de cable, ¿cuántas horas llevan de trabajo?
# 7.   ¿Cuánto tiempo transcurrió para que se completara la obra?

# %% [markdown]
# # Solución

# %% [markdown]
# **1)**

# %%
# 1
def calculate_cable_length(hours):
    return 1.85 * hours

# %% [markdown]
# **2)**

# %% [markdown]
# La variable dependiente es el largo del cable en kilómetros<br/>
# La variable independiente es el tiempo en horas

# %% [markdown]
# **3)**

# %% [markdown]
# Dominio de la función $$D:\{x|0\leq x\leq3567,6\}$$

# %% [markdown]
# **4)**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,3569)

plt.figure(figsize=(8, 6))
plt.plot(x, calculate_cable_length(x), label='y = 1.85x')

plt.title("Relación entre el largo del cable instalado y el tiempo transcurrido")
plt.xlabel('tiempo (horas)')
plt.ylabel('largo cable (kilómetros)')
plt.legend()

plt.show()

# %% [markdown]
# **5)**

# %%
def main():
    print(f"en 148 horas se han instalado {calculate_cable_length(148):_} km de cable")
    print(f"en 2300 horas se han instalado {calculate_cable_length(2300):_} km de cable")
    
main()
# Out:
# en 148 horas se han instalado 273.8 km de cable
# en 2300 horas se han instalado 4_255.0 km de cable

# %% [markdown]
# **6)**

# %%
# 6
def calculate_time(km):
    return round(km / 1.85,1)

def main():
    print(f"Los 3.480 km de cable se han instalado en {calculate_time(3480):_} horas")

main()
# Out:
# Los 3.480 km de cable se han instalado en 1_881.1

# %% [markdown]
# **7)**

# %%
def main():
    print(f"Los 6.600 km de cable se instalaron en {calculate_time(6600):_} horas")
    
main()
# Out:
# Los 6.600 km de cable se instalaron en 3_567.6 horas

# %% [markdown]
# # Problema 5

# %% [markdown]
# Un turista ha llegado a Santiago y desea conocer algunos lugares de la ciudad. Ha decidido visitar el Palacio de la Moneda y desde ahí trasladarse al centro comercial "Costanera Center", utilizando algún medio de transporte que ofrece la ciudad.
#
# Si se traslada en metro deberá abordar en estación La Moneda y bajar en la estación Tobalaba ($9$ estaciones). La función $f(t)$ permite calcular la distancia recorrida utilizando el metro (en kilómetros) transcurridos $t$ minutos.
#
# $$f(t) = 0,4t$$
#
# Si se traslada en bus, el turista podrá observar la ciudad y otros atractivos en su viaje. La función $g(t)$ permite calcular la distancia recorrida en bus (en kilómetros) transcurridos $t$ minutos.
#
# $$g(t) = 0,3t$$
#
# Según la información anterior:
#
# 1. Grafique ambas funciones, indicando el nombre de cada eje junto con su unidad de medida. Para realizar el gráfico utilice la biblioteca *Matplotlib*.
# 2.  Si se sabe que el metro se demora $1,2$ minutos en llegar desde una estación a otra y espera $30$ segundos en cada estación, indique el dominio contextualizado para $f(t)$.
# 3. Mediante análisis gráfico, indique cuál medio de transporte es más conveniente en términos de tiempo, para el turista. Justifique.
# 4.  Si se sabe que desde estación La Moneda hasta Tobalaba son aproximadamente $6$ kilómetros ¿cuántos tiempo tardará el turista en llegar a su destino con cada una de las opciones?

# %% [markdown]
# # Solución

# %% [markdown]
# **1)**

# %%
# 1
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0, 14.8)

y1 = 0.4 * t
y2 = 0.3 * t

plt.plot(t, y1, label='metro')
plt.plot(t, y2, label='bus')

plt.title("Relación entre la distancia recorrida y el tiempo")
plt.xlabel('tiempo (minutos)')
plt.ylabel('distancia (kilometros)')
plt.legend()

plt.show()

# %% [markdown]
# **2)**

# %% [markdown]
# Considerando que el turista llega justo después de que el metro sale de la estación Moneda, debe esperar $1,2 * 9$ minutos, más $30 * 8$ segundos en cada estación, lo que resulta:
# $$ (1.2 * 9) + (0.5 * 8)$$
# $$ 14.8$$
#
# Que representa el máximo de minutos que el turista debe esperar, asi que el dominio de la función es:
#
# $$ D:\{x|x \in [0, 14.8]\}$$

# %% [markdown]
# **3)**

# %% [markdown]
# El medio de transporte más conveniente para viajar es el metro, según la gráfica a mayor tiempo transcurrido más kilómetros se avanza en relación a la distancia recorrida viajando en bus

# %% [markdown]
# **4)**

# %%
def metro_time(km):
    return km/0.4

def bus_time(km):
    return km/0.3

def main():
    print(f"El turista se demora aproximadamente {metro_time(6)} minutos en llegar a su destino en metro")
    print(f"El turista se demora aproximadamente {bus_time(6)} minutos en llegar a su destino en bus")
    
main()
# Out:
# El turista se demora aproximadamente 15.0 minutos en llegar a su destino en metro
# El turista se demora aproximadamente 20.0 minutos en llegar a su destino en bus

# %% [markdown]
# # Problema 6

# %% [markdown]
# La temperatura de un servidor (en °C) puede ser modelada mediante la función
#
# $$T(t) = -0,5 t^{2} + 3 t + 20$$
#
# donde $t$ corresponde al tiempo transcurrido (en horas) en un día laboral. Considere que la jornada laboral comienza a las 08:00 horas y termina a las 17:00 horas.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
# 2.  Determine el dominio contextualizado del problema.
# 3.  Grafique la función utilizando *Python*.
# 4.  Mediante un análisis gráfico, estime cuándo el servidor alcanza la máxima temperatura y calcule cuánto es.
# 5.  Determine la temperatura del servidor a las 13:00 horas y al finalizar la jornada laboral.

# %% [markdown]
# # Solución

# %%
def calculate_temperature(time):
    return  (-0.5) * time**2 + 3 * time + 20

# %% [markdown]
# **1)**

# %% [markdown]
# La variable dependiente es la temperatura en °C <br />
# La variable independiente es el tiempo en horas

# %% [markdown]
# **2)**

# %% [markdown]
# $$ D:\{x|x \in [0, 9]\}$$

# %% [markdown]
# **3)**

# %%
# 3
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np

times = pd.date_range(start='08:00', end='17:00', freq='h')

t = np.arange(len(times))


fig, ax = plt.subplots()
ax.plot(times, calculate_temperature(t), marker='o', linestyle='-')
ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.xticks(rotation=45)

ax.set_title("Realción entre la temperatura de un servidor y el tiempo transcurrido")
ax.set_xlabel('Tiempo (horas)')
ax.set_ylabel('Temperatura (°C)')
plt.show()

# %% [markdown]
# **4)**

# %% [markdown]
# Gráficamente podemos decir que a las 11:00 se registra la temperatura más alta, la cual pertenece al rango $[22.5,25.0]$. (analizando la función sabemos que la temperatura es 24.5 °C)

# %% [markdown]
# **5)**

# %%
def main():
    print(f"La temperatura del servidor a las 13:00 horas (t = 5) es {calculate_temperature(5)}°C")
    print(f"La temperatura del servidor a las 17:00 horas (t = 9) es {calculate_temperature(9)}°C")
    
main()
# Out:
# La temperatura del servidor a las 13:00 horas (t = 5) es 22.5°C
# La temperatura del servidor a las 17:00 horas (t = 9) es 6.5°C

# %% [markdown]
# # Problema 7

# %% [markdown]
# El número de usuarios de una red social se puede modelar mediante la función:
#
# $$U(t) = \frac{1.000}{1+9e^{-0.5t}}$$
#
# donde $t$ corresponde al tiempo transcurrido en meses.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
# 2.  Determine la cantidad de usuarios transcurridos $12$ meses.
# 3.  Grafique la función, utilizando la librería *Matplotlib*, para los primeros dos años de funcionamiento.
# 4.  ¿Cuánto tiempo debe pasar para que la red social llegue a $800$ usuarios?

# %% [markdown]
# # Solución

# %% [markdown]
# **1)**

# %% [markdown]
# La variable dependiente es la cantidad de usuarios <br />
# La variable independiente es el tiempo en meses

# %% [markdown]
# **2)**

# %%
# 2
import numpy as np
def number_of_users(time):
    return 1000 / (1 + 9*(np.exp(-0.5*time)))

def main():
    print(f"La cantidad de usuarios transcurridos 12 meses es de {int(number_of_users(12))} aproximadamente")
    
main()
# Out:
# La cantidad de usuarios transcurridos 12 meses es de 978 aproximadamente

# %% [markdown]
# **3)**

# %%
# 3
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np

times = pd.date_range(start='2024-01-01', end='2026-01-01', freq='ME')

t = np.arange(len(times))

fig, ax = plt.subplots()
ax.plot(times, number_of_users(t), marker='o', linestyle='-')

plt.xticks(rotation=45)

# Add labels and title
ax.set_xlabel('Fecha')
ax.set_ylabel('Número de usuarios')
plt.show()

# %% [markdown]
# **4)**

# %%
import numpy as np
from scipy.optimize import fsolve

def u(t):
    return 1000 / (1 + 9*(np.exp(-0.5*t))) - 800

t = np.linspace(0,25,1)
sol = fsolve(u, t)
def main():
    print(f"Tiene que pasar al menos {sol[0]:.1f} meses para que la red social tenga 800 usuarios")
    
main()
# Out:
# Tiene que pasar al menos 7.2 meses para que la red social tenga 800 usuarios

# %% [markdown]
# # Problema 8

# %% [markdown]
# El tiempo de ejecución de un algoritmo de ordenación (en segundos) se puede modelar mediante la función:
#
# $$A(n) = 0,01n^{2} + 0,5n + 2$$
#
# donde $n$ corresponde a la cantidad de elementos a ordenar. El algoritmo funciona desde las 23:00 horas hasta las 06:00 horas y debe ordenar $1.562$ elementos.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine el dominio contextualizado de la función.
# 3. Determine el tiempo de ejecución para ordenar $1.200$ elementos.
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $A(n)$.
# 5. ¿Cuántos elementos ordena luego de $6$ horas de funcionamiento?

# %% [markdown]
# # Solución

# %% [markdown]
# **1)**

# %% [markdown]
# La variable dependiente es el tiempo de ejecución del algoritmo en segundos<br />
# La variable independiente es el número de elementos a ordenar

# %% [markdown]
# **2)**

# %% [markdown]
# $$ D:\{x|x \in [0, 1562]\}$$

# %% [markdown]
# **3)**

# %%
# 3
def execution_time(n_elements):
    return (0.01)*n_elements**2 + 0.5*n_elements + 2

def main():
    print(f"El tiempo de ejecución para ordenar 1200 elementos es de {execution_time(1200):_} segundos")

main()
# Out:
# El tiempo de ejecución para ordenar 1200 elementos es de 15_002.0 segundos

# %% [markdown]
# **4)**

# %%
# 4
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,1563)

plt.plot(x, execution_time(x))

plt.title("Relación entre el tiempo de ejecución de un algoritmo y la cantidad de elementos que ordena")
plt.xlabel('número de elementos')
plt.ylabel('tiempo (segundos)')

plt.show()

# %% [markdown]
# **5)**

# %%
# 5
import numpy as np
from scipy.optimize import fsolve

def hours_to_seconds(hours):
    return hours * 60 * 60

def exec_time_6h(n_elements):
    return 0.01 * n_elements ** 2 + 0.5 * n_elements - 2 - hours_to_seconds(6)

n = np.linspace(0,1562,1)

sol = fsolve(exec_time_6h, n)

def main(): 
    print(f"Luego de 6 horas se han ordenado {sol[0]:.0f} elementos")
    
main()
# Out:
# Luego de 6 horas se han ordenado 1445 elementos

# %% [markdown]
# # Problema 9

# %% [markdown]
# El consumo de energía (en $kWh$) de un *Data Center* puede ser modelado por la función:
#
#  $$E(t) = 50\cdot \log(t + 1) + 200$$
#
# donde $t$ corresponde al tiempo (en horas) desde el inicio del monitoreo.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine el consumo de energía del *Data Center* después de $5$ horas.
# 3. ¿Luego de cuántas horas el consumo será de $350$ kWh?
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $E(t)$.

# %% [markdown]
# # Solución

# %% [markdown]
# **1)**

# %% [markdown]
# La variable dependiente es el consume de energía en KWh <br />
# La variable independiente es el tiempo en horas.

# %% [markdown]
# **2)**

# %%
# 2
import numpy as np

def calc_energy_consumption(time):
    return 50 * np.log10(time + 1) + 200 

def main():
    print(f"El consumo de energía del Data center después de 5 horas es de {calc_energy_consumption(5):.0f} kWh aproximadamente")  

main()
# Out:
# El consumo de energía del Data center después de 5 horas es de 239 kWh aproximadamente

# %% [markdown]
# **3)**

# %%
import numpy as np
from scipy.optimize import fsolve

def calc_e_350(t):
    return 50 * np.log10(t+1) - 150

t = np.linspace(0,1000, 1)
sol = fsolve(calc_e_350, t)

def main():
    print(f'han pasado {sol[0]:.0f} horas aproximadamente para consumir 350 kWh')
    
main()
# Out:
# han pasado 999 horas aproximadamente para consumir 350 kWh

# %% [markdown]
# **4)**

# %%
# 4
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0, 1000)

plt.plot(t, calc_energy_consumption(t))
plt.xlabel('Tiempo (horas)')
plt.ylabel('Energía (kWh)')
plt.show()

# %% [markdown]
# # Problema 10

# %% [markdown]
# En gestión de proyectos, es crucial entender cómo se distribuye la carga de trabajo a lo largo del tiempo para planificar recursos, tiempo y esfuerzos de manera eficiente. Un fenómeno común es la disminución exponencial de la carga de trabajo, donde el esfuerzo requerido es mayor al inicio del proyecto y disminuye gradualmente a medida que se completan las tareas principales.
#
# Esta disminución exponencial puede modelarse matemáticamente para predecir y gestionar el trabajo de manera efectiva.
#
# <br>
#
# Un estudio sobre gestión de proyectos sostiene que la carga de trabajo en un proyecto (en porcentaje) puede ser modelada por la función:
#
# $$W(t) = 100e^{-0.1t}$$
#
# donde $t$ corresponde al tiempo transcurrido (en semanas) desde el inicio del proyecto.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine la carga de trabajo al inicio del proyecto.
# 3. ¿Cuál será la carga de trabajo luego de transcurridas $4$ semanas desde el inicio del proyecto?
# 4. Si el proyecto duró $12$ semanas, ¿es correcto afirmar que la carga de trabajo llegó al $20\%$?
# 5. ¿Cuántas semanas han pasado desde el inicio del proyecto para que la carga de trabajo sea de $55\%$?
# 6. Utilizando *Matplotlib*, grafique la función considerando un tiempo máximo de $12$ semanas.

# %% [markdown]
# # Solución

# %% [markdown]
# **1)**

# %% [markdown]
# La variable dependiente es la carga de trabajo en porcentaje <br/>
# La variable independiente es el tiempo transcurrido en semanas

# %% [markdown]
# **2)**

# %%
# 2
import numpy as np

def calc_work_load(time):
    return 100 * np.exp((-0.1)* time)

def main():
    print(f"La carga de trabajo al inicio del proyecto es de {calc_work_load(0)}%")

main()
# Out:
# La carga de trabajo al inicio del proyecto es de 100.0%

# %% [markdown]
# **3)**

# %%
# 3
def main():
    print(f"La carga de trabajo luego de transcurridas 4 semanas es de {calc_work_load(4):.1f}% aproximadamente")

main()
# Out:
# La carga de trabajo luego de transcurridas 4 semanas es de 67.0% aproximadamente

# %% [markdown]
# **4)**

# %%
# 4
def main():
    print(f"La carga de trabajo luego de transcurridas 12 semanas es de {calc_work_load(12):.1f}% aproximadamente")
    if int(calc_work_load(12)) == 20:
        print('La afirmación es correcta')
    else:
        print("La afirmación es incorrecta")
    
main()
# Out:
# La carga de trabajo luego de transcurridas 12 semanas es de 30.1% aproximadamente
# La afirmación es incorrecta

# %% [markdown]
# **5)**

# %%
# 5
import numpy as np
from scipy.optimize import fsolve

def work_load_55(t):
    return 100 * np.exp(-0.1 * t) - 55

t = np.linspace(0, 12, 1)
sol = fsolve(work_load_55, t)

def main():
    print(f"Han pasado aproximadamente {sol[0]:.1f} semanas para que la carga de trabajo sea de 55%")

main()
# Out:
# Han pasado aproximadamente 6.0 semanas para que la carga de trabajo sea de 55%

# %% [markdown]
# **6)**

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0,13)

plt.plot(t,calc_work_load(t))
plt.xticks(np.arange(0,13,1))
plt.yticks(np.arange(0,110,10))
plt.ylim(0,100)
plt.xlabel('Tiempo (semanas)')
plt.ylabel('Carga de trabajo (%)')
plt.grid(True)
plt.show()
